# %% [markdown]
# # Pymaceuticals Inc.
# Capomulin looks to be a promising treatment.
#
# ### Analysis
#
# - Capomulin had the lowest average tumor volume over the course of the study. Only Ramicane could compete with Capomulin's results.
# - Many drug regimens saw tumor volume increase over the course of treatments, but not Capomulin.
# - Unfortunately, the average tumor volume had a high correlation with the size of the mouse.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# Turn off warnings
import warnings
warnings.filterwarnings("ignore")

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single DataFrame
mouse_study_complete = pd.merge(study_results, mouse_metadata, how="left", on=["Mouse ID"])

# Display the data table for preview
mouse_study_complete.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0                45.0                 0    Capomulin
# 1     f932          0                45.0                 0     Ketapril
# 2     g107          0                45.0                 0     Ketapril
# 3     a457          0                45.0                 0     Ketapril
# 4     c819          0                45.0                 0     Ketapril
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1    Male          15          29
# 2  Female           2          29
# 3  Female          11          30
# 4    Male          21          25

# %%
# Checking the number of mice.
mouse_check = len(mouse_study_complete["Mouse ID"].unique())
mouse_check
# Out:
# 249

# %%
# Our data should be uniquely identified by Mouse ID and Timepoint
# Get the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
duplicate_records = mouse_study_complete[mouse_study_complete.duplicated(subset=["Mouse ID", "Timepoint"])]
duplicate_mouse = duplicate_records["Mouse ID"].unique()
duplicate_mouse
# Out:
# array(['g989'], dtype=object)

# %%
# Optional: Get all the data for the duplicate mouse ID. 
dup_mouse_id = duplicate_mouse[0]
dup_mouse_data = mouse_study_complete.loc[mouse_study_complete["Mouse ID"] == dup_mouse_id, :]
dup_mouse_data
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 107      g989          0           45.000000                 0     Propriva
# 137      g989          0           45.000000                 0     Propriva
# 329      g989          5           48.786801                 0     Propriva
# 360      g989          5           47.570392                 0     Propriva
# 620      g989         10           51.745156                 0     Propriva
# 681      g989         10           49.880528                 0     Propriva
# 815      g989         15           51.325852                 1     Propriva
# 869      g989         15           53.442020                 0     Propriva
# 950      g989         20           55.326122                 1     Propriva
# 1111     g989         20           54.657650                 1     Propriva
# 1195     g989         25           56.045564                 1     Propriva
# 1380     g989         30           59.082294                 1     Propriva
# 1592     g989         35           62.570880                 2     Propriva
#
#          Sex  Age_months  Weight (g)
# 107   Female          21          26
# 137   Female          21          26
# 329   Female          21          26
# 360   Female          21          26
# 620   Female          21          26
# 681   Female          21          26
# 815   Female          21          26
# 869   Female          21          26
# 950   Female          21          26
# 1111  Female          21          26
# 1195  Female          21          26
# 1380  Female          21          26
# 1592  Female          21          26

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
cleaned_mice_data = mouse_study_complete[(mouse_study_complete["Mouse ID"] != dup_mouse_id)]
cleaned_mice_data.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0                45.0                 0    Capomulin
# 1     f932          0                45.0                 0     Ketapril
# 2     g107          0                45.0                 0     Ketapril
# 3     a457          0                45.0                 0     Ketapril
# 4     c819          0                45.0                 0     Ketapril
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1    Male          15          29
# 2  Female           2          29
# 3  Female          11          30
# 4    Male          21          25

# %%
# Checking the number of mice in the clean DataFrame.
mouse_count = len(cleaned_mice_data["Mouse ID"].unique())
mouse_count
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume.
avg_tumor_per_drug = cleaned_mice_data.groupby("Drug Regimen")["Tumor Volume (mm3)"].mean()
med_tumor_per_drug = cleaned_mice_data.groupby("Drug Regimen")["Tumor Volume (mm3)"].median()
var_tumor_per_drug = cleaned_mice_data.groupby("Drug Regimen")["Tumor Volume (mm3)"].var()
std_tumor_per_drug = cleaned_mice_data.groupby("Drug Regimen")["Tumor Volume (mm3)"].std()
sem_tumor_per_drug = cleaned_mice_data.groupby("Drug Regimen")["Tumor Volume (mm3)"].sem()

# Assemble the resulting series into a single summary DataFrame.
man_sum_stats = pd.DataFrame({"Mean Tumor Volume": avg_tumor_per_drug, "Median Tumor Volume": med_tumor_per_drug,
                              "Tumor Volume Variance": var_tumor_per_drug, "Tumor Volume Std. Dev.": std_tumor_per_drug,
                              "Tumor Volume Std. Err.": sem_tumor_per_drug})
man_sum_stats
# Out:
#               Mean Tumor Volume  Median Tumor Volume  Tumor Volume Variance  \
# Drug Regimen
# Capomulin             40.675741            41.557809              24.947764
# Ceftamin              52.591172            51.776157              39.290177
# Infubinol             52.884795            51.820584              43.128684
# Ketapril              55.235638            53.698743              68.553577
# Naftisol              54.331565            52.509285              66.173479
# Placebo               54.033581            52.288934              61.168083
# Propriva              52.320930            50.446266              43.852013
# Ramicane              40.216745            40.673236              23.486704
# Stelasyn              54.233149            52.431737              59.450562
# Zoniferol             53.236507            51.818479              48.533355
#
#               Tumor Volume Std. Dev.  Tumor Volume Std. Err.
# Drug Regimen
# Capomulin                   4.994774                0.329346
# Ceftamin                    6.268188                0.469821
# Infubinol                   6.567243                0.492236
# Ketapril                    8.279709                0.603860
# Naftisol                    8.134708                0.596466
# Placebo                     7.821003                0.581331
# Propriva                    6.622085                0.544332
# Ramicane                    4.846308                0.320955
# Stelasyn                    7.710419                0.573111
# Zoniferol                   6.966589                0.516398

# %%
# A more advanced method to generate a summary statistics table of mean, median, variance, standard deviation,
# and SEM of the tumor volume for each regimen (only one method is required in the solution)

# Using the aggregation method, produce the same summary statistics in a single line
agg_sum_stats = cleaned_mice_data.groupby("Drug Regimen").agg({"Tumor Volume (mm3)":["mean", "median", "var", "std", "sem"]})
agg_sum_stats
# Out:
#              Tumor Volume (mm3)
#                            mean     median        var       std       sem
# Drug Regimen
# Capomulin             40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin              52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol             52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril              55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol              54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo               54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva              52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane              40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn              54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol             53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using Pandas.

# Find the number of Timepoints per Drug Regimen (each row is a unique "Timepoint" so value_counts() works here)
drug_timepoints = cleaned_mice_data["Drug Regimen"].value_counts()

# Plot the data with Pandas
drug_timepoints.plot(ylabel="# of Observed Mouse Timepoints", kind="bar", figsize=(6,4));

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using pyplot.
# Use the same series we created in the cell above
pills = np.arange(len(drug_timepoints))
tick_locations = [pill for pill in pills]
plt.bar(pills, drug_timepoints, align="center")
plt.xticks(tick_locations, drug_timepoints.index, rotation="vertical")
plt.xlabel("Drug Regimen")
plt.ylabel("# of Observed Mouse Timepoints")
plt.show()
plt.tight_layout()

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas

# Find counts of male and female mice
# I feel like finding the unique number of mice first would be the more accurate way to go here:
    # unique_mice = mouse_study_complete.drop_duplicates(subset=["Mouse ID"])

gender_count = cleaned_mice_data["Sex"].value_counts()

# Show Pie Chart
pandas_pie_chart = gender_count.plot(kind="pie",y=gender_count, ylabel="Sex", autopct="%1.1f%%")

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
labels = ["Male", "Female"]
plt.pie(gender_count, labels=labels, autopct="%1.1f%%")
plt.ylabel("Sex")
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Start by getting the last (greatest, aka max) timepoint for each mouse
timepoint_per_mouse = mouse_study_complete.groupby("Mouse ID")["Timepoint"].max()

# Merge this group df with the original DataFrame to get the tumor volume at the last timepoint
study_results = pd.merge(timepoint_per_mouse, mouse_study_complete, on=["Mouse ID", "Timepoint"])
study_results
# Out:
#     Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0       a203         45           67.973419                 2    Infubinol
# 1       a251         45           65.525743                 1    Infubinol
# 2       a262         45           70.717621                 4      Placebo
# 3       a275         45           62.999356                 3     Ceftamin
# 4       a366         30           63.440686                 1     Stelasyn
# ..       ...        ...                 ...               ...          ...
# 244     z435         10           48.710661                 0     Propriva
# 245     z578         45           30.638696                 0     Ramicane
# 246     z581         45           62.754451                 3    Infubinol
# 247     z795         45           65.741070                 3     Naftisol
# 248     z969         45           73.867845                 4     Naftisol
#
#         Sex  Age_months  Weight (g)
# 0    Female          20          23
# 1    Female          21          25
# 2    Female          17          29
# 3    Female          20          28
# 4    Female          16          29
# ..      ...         ...         ...
# 244  Female          12          26
# 245    Male          11          16
# 246  Female          24          25
# 247  Female          13          29
# 248    Male           9          30
#
# [249 rows x 8 columns]

# %%
# Put treatments into a list for for loop (and later for plot labels)
treatments = ["Capomulin", "Ramicane", "Infubinol", "Ceftamin"]

# Create empty list to fill with tumor vol data (for plotting)
tumor_volume = []

# Calculate the IQR and quantitatively determine if there are any potential outliers. 

for drug in treatments:
    
    # Locate the rows which contain mice on each drug and get the tumor volumes
    tumor_vol_df = study_results.loc[study_results["Drug Regimen"] == drug, "Tumor Volume (mm3)"]
    
    # Add subset
    tumor_volume.append(tumor_vol_df)    
    
    
    quartiles = tumor_vol_df.quantile([.25,.5,.75])
    lowerq = quartiles[0.25]
    upperq = quartiles[0.75]
    iqr = upperq-lowerq
    lower_bound = lowerq - (1.5*iqr)
    upper_bound = upperq + (1.5*iqr)

    # Determine outliers using upper and lower bounds
    outliers = tumor_vol_df.loc[(tumor_vol_df > upper_bound) | (tumor_vol_df < lower_bound)]
    print(f"{drug}'s potential outliers: {outliers}")
# Out:
# Capomulin's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)
# Ramicane's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)
# Infubinol's potential outliers: 31    36.321346
# Name: Tumor Volume (mm3), dtype: float64
# Ceftamin's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)

# %%
# Generate a box plot that shows the distrubution of the tumor volume for each treatment group.

plt.boxplot(tumor_volume, labels=treatments, flierprops = dict(markerfacecolor = "red", markersize="12"))
plt.ylabel("Final Tumor Volume (mm3)")
plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a single mouse treated with Capomulin

# Isolate a mouse
capomulin_mice = cleaned_mice_data.loc[(cleaned_mice_data["Drug Regimen"] == "Capomulin"), :]
mouse = capomulin_mice.iloc[12,0]
capomulin_mouse = capomulin_mice.loc[capomulin_mice["Mouse ID"] == mouse, :]

# Grab x and y axis for line plot
x_time = capomulin_mouse["Timepoint"]
y_t_vol = capomulin_mouse["Tumor Volume (mm3)"]

# Line plot:
plt.plot(x_time, y_t_vol)
plt.title(f"Capomulin treatment of mouse {mouse}")
plt.ylabel("Tumor Volume (mm3)")
plt.xlabel("Timepoint (days)")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Generate a scatter plot of mouse weight vs. the average observed tumor volume for the entire Capomulin regimen
#capomulin_mice
mouse_weight = capomulin_mice.groupby("Mouse ID")["Weight (g)"].unique().astype(int)
avg_obs_tumor_vol = capomulin_mice.groupby("Mouse ID")["Tumor Volume (mm3)"].mean()

# Plot data on scatter plot
plt.scatter(mouse_weight, avg_obs_tumor_vol)
plt.ylabel("Average Tumor Volume (mm3)")
plt.xlabel("Weight (g)")
plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
from scipy.stats import linregress

# %%
# Calculate the correlation coefficient and a linear regression model 
# for mouse weight and average observed tumor volume for the entire Capomulin regimen
(slope, intercept, rvalue, pvalue, stderr) = linregress(mouse_weight, avg_obs_tumor_vol)
regress_values = mouse_weight * slope + intercept
line_eq = str(round(slope,2)) + str(round(intercept,2))

# print the correlation
print(f"The correlation between mouse weight and the average tumor volume is {round(st.pearsonr(mouse_weight,avg_obs_tumor_vol)[0],2)}")

# Plot the linear regression to scatter plot
plt.scatter(mouse_weight, avg_obs_tumor_vol)
plt.plot(mouse_weight, regress_values, "r-")
plt.annotate(line_eq, (5.8, 0.8), fontsize=12,color="red")
plt.ylabel("Average Tumor Volume (mm3)")
plt.xlabel("Weight (g)")
plt.show()
# Out:
# The correlation between mouse weight and the average tumor volume is 0.84
